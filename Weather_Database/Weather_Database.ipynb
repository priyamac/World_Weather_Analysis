# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
from config import weather_api_key
import requests 
import time
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 625

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kapaa
# Processing Record 2 of Set 1 | lavrentiya
# Processing Record 3 of Set 1 | georgetown
# Processing Record 4 of Set 1 | rikitea
# Processing Record 5 of Set 1 | tual
# Processing Record 6 of Set 1 | panzhihua
# Processing Record 7 of Set 1 | cape town
# Processing Record 8 of Set 1 | defiance
# Processing Record 9 of Set 1 | punta arenas
# Processing Record 10 of Set 1 | srednekolymsk
# Processing Record 11 of Set 1 | ovre ardal
# Processing Record 12 of Set 1 | codrington
# Processing Record 13 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 14 of Set 1 | bam
# Processing Record 15 of Set 1 | saint-philippe
# Processing Record 16 of Set 1 | vrangel
# Processing Record 17 of Set 1 | mahebourg
# Processing Record 18 of Set 1 | new norfolk
# Processing Record 19 of Set 1 | hobart
# Processing Record 20 of Set 1 | kodiak
# Processing Record 21 of Set 1 | hornepayne
# Processing Record 22 of Set 1 | vaini
# Processing Record 23 of Set 1 | richards bay
# Processing Record 24 of Set 1 | torbay
# Processing Record 25 of Set 1 | hilo
# Processing Record 26 of Set 1 | berdigestyakh
# Processing Record 27 of Set 1 | komsomolskiy
# Processing Record 28 of Set 1 | busselton
# Processing Record 29 of Set 1 | san cristobal
# Processing Record 30 of Set 1 | butaritari
# Processing Record 31 of Set 1 | mataura
# Processing Record 32 of Set 1 | cidreira
# Processing Record 33 of Set 1 | straumen
# Processing Record 34 of Set 1 | viedma
# Processing Record 35 of Set 1 | alghero
# Processing Record 36 of Set 1 | hamilton
# Processing Record 37 of Set 1 | grand gaube
# Processing Record 38 of Set 1 | puerto ayora
# Processing Record 39 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 40 of Set 1 | upernavik
# Processing Record 41 of Set 1 | fomboni
# Processing Record 42 of Set 1 | jamestown
# Processing Record 43 of Set 1 | ushuaia
# Processing Record 44 of Set 1 | hasaki
# Processing Record 45 of Set 1 | zanjan
# Processing Record 46 of Set 1 | auki
# Processing Record 47 of Set 1 | avarua
# Processing Record 48 of Set 1 | casablanca
# Processing Record 49 of Set 1 | tautira
# Processing Record 50 of Set 1 | paraiso
# Processing Record 1 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 2 of Set 2 | barrow
# Processing Record 3 of Set 2 | port alfred
# Processing Record 4 of Set 2 | kavaratti
# Processing Record 5 of Set 2 | castro
# Processing Record 6 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 7 of Set 2 | pevek
# Processing Record 8 of Set 2 | acapulco
# Processing Record 9 of Set 2 | bengkulu
# Processing Record 10 of Set 2 | te anau
# Processing Record 11 of Set 2 | anuradhapura
# Processing Record 12 of Set 2 | talcahuano
# Processing Record 13 of Set 2 | waitati
# Processing Record 14 of Set 2 | atuona
# Processing Record 15 of Set 2 | nerchinskiy zavod
# Processing Record 16 of Set 2 | victor harbor
# Processing Record 17 of Set 2 | buchanan
# Processing Record 18 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 19 of Set 2 | harper
# Processing Record 20 of Set 2 | gizo
# Processing Record 21 of Set 2 | chuy
# Processing Record 22 of Set 2 | inirida
# Processing Record 23 of Set 2 | viligili
# City not found. Skipping...
# Processing Record 24 of Set 2 | altay
# Processing Record 25 of Set 2 | shevchenkove
# Processing Record 26 of Set 2 | vanavara
# Processing Record 27 of Set 2 | oktyabrskiy
# Processing Record 28 of Set 2 | belmonte
# Processing Record 29 of Set 2 | itacoatiara
# Processing Record 30 of Set 2 | chokurdakh
# Processing Record 31 of Set 2 | gavle
# Processing Record 32 of Set 2 | coihueco
# Processing Record 33 of Set 2 | elizabeth city
# Processing Record 34 of Set 2 | omboue
# Processing Record 35 of Set 2 | anito
# Processing Record 36 of Set 2 | arrifes
# Processing Record 37 of Set 2 | todos santos
# Processing Record 38 of Set 2 | carnarvon
# Processing Record 39 of Set 2 | ukiah
# Processing Record 40 of Set 2 | sibolga
# Processing Record 41 of Set 2 | port elizabeth
# Processing Record 42 of Set 2 | cayenne
# Processing Record 43 of Set 2 | jalu
# Processing Record 44 of Set 2 | mandera
# Processing Record 45 of Set 2 | hofn
# Processing Record 46 of Set 2 | madang
# Processing Record 47 of Set 2 | bowen
# Processing Record 48 of Set 2 | yellowknife
# Processing Record 49 of Set 2 | severo-kurilsk
# Processing Record 50 of Set 2 | waipawa
# Processing Record 1 of Set 3 | qaanaaq
# Processing Record 2 of Set 3 | ahipara
# Processing Record 3 of Set 3 | korla
# Processing Record 4 of Set 3 | esperance
# Processing Record 5 of Set 3 | bilma
# Processing Record 6 of Set 3 | thompson
# Processing Record 7 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 8 of Set 3 | nanortalik
# Processing Record 9 of Set 3 | turukhansk
# Processing Record 10 of Set 3 | nuevo laredo
# Processing Record 11 of Set 3 | bambanglipuro
# Processing Record 12 of Set 3 | chingirlau
# Processing Record 13 of Set 3 | dicabisagan
# Processing Record 14 of Set 3 | fort nelson
# Processing Record 15 of Set 3 | clyde river
# Processing Record 16 of Set 3 | nome
# Processing Record 17 of Set 3 | guerrero negro
# Processing Record 18 of Set 3 | qaqortoq
# Processing Record 19 of Set 3 | aire-sur-la-lys
# Processing Record 20 of Set 3 | vychegodskiy
# Processing Record 21 of Set 3 | salina
# Processing Record 22 of Set 3 | white rock
# Processing Record 23 of Set 3 | muisne
# Processing Record 24 of Set 3 | ust-charyshskaya pristan
# Processing Record 25 of Set 3 | victoria
# Processing Record 26 of Set 3 | la ronge
# Processing Record 27 of Set 3 | buraydah
# Processing Record 28 of Set 3 | nhulunbuy
# Processing Record 29 of Set 3 | albany
# Processing Record 30 of Set 3 | nueve de julio
# Processing Record 31 of Set 3 | muyezerskiy
# Processing Record 32 of Set 3 | iskateley
# Processing Record 33 of Set 3 | ribeira grande
# Processing Record 34 of Set 3 | magomeni
# Processing Record 35 of Set 3 | jorochito
# Processing Record 36 of Set 3 | bathsheba
# Processing Record 37 of Set 3 | portland
# Processing Record 38 of Set 3 | norman wells
# Processing Record 39 of Set 3 | tasiilaq
# Processing Record 40 of Set 3 | tarata
# Processing Record 41 of Set 3 | rocha
# Processing Record 42 of Set 3 | road town
# Processing Record 43 of Set 3 | necochea
# Processing Record 44 of Set 3 | bambous virieux
# Processing Record 45 of Set 3 | khasan
# Processing Record 46 of Set 3 | vila velha
# Processing Record 47 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 48 of Set 3 | hervey bay
# Processing Record 49 of Set 3 | maarianhamina
# Processing Record 50 of Set 3 | kolosovka
# Processing Record 1 of Set 4 | rozkishne
# Processing Record 2 of Set 4 | liverpool
# Processing Record 3 of Set 4 | guadalupe
# Processing Record 4 of Set 4 | adrar
# Processing Record 5 of Set 4 | comodoro rivadavia
# Processing Record 6 of Set 4 | sur
# Processing Record 7 of Set 4 | kaitangata
# Processing Record 8 of Set 4 | nikolskoye
# Processing Record 9 of Set 4 | puerto carreno
# Processing Record 10 of Set 4 | khonuu
# City not found. Skipping...
# Processing Record 11 of Set 4 | gualdo tadino
# Processing Record 12 of Set 4 | east london
# Processing Record 13 of Set 4 | saskylakh
# Processing Record 14 of Set 4 | pisco
# Processing Record 15 of Set 4 | alice springs
# Processing Record 16 of Set 4 | half moon bay
# Processing Record 17 of Set 4 | san quintin
# Processing Record 18 of Set 4 | tura
# Processing Record 19 of Set 4 | kokopo
# Processing Record 20 of Set 4 | beloha
# Processing Record 21 of Set 4 | bow island
# Processing Record 22 of Set 4 | kharp
# Processing Record 23 of Set 4 | emerald
# Processing Record 24 of Set 4 | sunamganj
# City not found. Skipping...
# Processing Record 25 of Set 4 | narsaq
# Processing Record 26 of Set 4 | nouadhibou
# Processing Record 27 of Set 4 | hithadhoo
# Processing Record 28 of Set 4 | copperas cove
# Processing Record 29 of Set 4 | ambon
# Processing Record 30 of Set 4 | ulaanbaatar
# Processing Record 31 of Set 4 | peace river
# Processing Record 32 of Set 4 | nybro
# Processing Record 33 of Set 4 | puerto baquerizo moreno
# Processing Record 34 of Set 4 | haimen
# Processing Record 35 of Set 4 | sao sebastiao do paraiso
# Processing Record 36 of Set 4 | san patricio
# Processing Record 37 of Set 4 | tanout
# Processing Record 38 of Set 4 | ponta delgada
# Processing Record 39 of Set 4 | ixtapa
# Processing Record 40 of Set 4 | lebu
# Processing Record 41 of Set 4 | bud
# Processing Record 42 of Set 4 | faanui
# Processing Record 43 of Set 4 | usak
# Processing Record 44 of Set 4 | oussouye
# Processing Record 45 of Set 4 | bealanana
# Processing Record 46 of Set 4 | tuatapere
# Processing Record 47 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 48 of Set 4 | miranda
# Processing Record 49 of Set 4 | roebourne
# Processing Record 50 of Set 4 | sisimiut
# Processing Record 1 of Set 5 | dikson
# Processing Record 2 of Set 5 | galesong
# Processing Record 3 of Set 5 | cockburn harbour
# City not found. Skipping...
# Processing Record 4 of Set 5 | pamplona
# Processing Record 5 of Set 5 | doctor arroyo
# Processing Record 6 of Set 5 | ongandjera
# Processing Record 7 of Set 5 | meulaboh
# Processing Record 8 of Set 5 | mount isa
# Processing Record 9 of Set 5 | zambezi
# Processing Record 10 of Set 5 | hermanus
# Processing Record 11 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 12 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 13 of Set 5 | jaicos
# Processing Record 14 of Set 5 | bardiyah
# Processing Record 15 of Set 5 | arraial do cabo
# Processing Record 16 of Set 5 | waycross
# Processing Record 17 of Set 5 | brae
# Processing Record 18 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 19 of Set 5 | lichuan
# Processing Record 20 of Set 5 | yandoon
# City not found. Skipping...
# Processing Record 21 of Set 5 | vostok
# Processing Record 22 of Set 5 | katsuura
# Processing Record 23 of Set 5 | manaure
# Processing Record 24 of Set 5 | ostrovnoy
# Processing Record 25 of Set 5 | baykit
# Processing Record 26 of Set 5 | redmond
# Processing Record 27 of Set 5 | bluff
# Processing Record 28 of Set 5 | cabo san lucas
# Processing Record 29 of Set 5 | sao filipe
# Processing Record 30 of Set 5 | artyom
# Processing Record 31 of Set 5 | bocas del toro
# Processing Record 32 of Set 5 | kahului
# Processing Record 33 of Set 5 | lasa
# Processing Record 34 of Set 5 | urfa
# City not found. Skipping...
# Processing Record 35 of Set 5 | ilulissat
# Processing Record 36 of Set 5 | meadow lake
# Processing Record 37 of Set 5 | souillac
# Processing Record 38 of Set 5 | neubrandenburg
# Processing Record 39 of Set 5 | nara
# Processing Record 40 of Set 5 | nadym
# Processing Record 41 of Set 5 | baleshwar
# Processing Record 42 of Set 5 | illapel
# Processing Record 43 of Set 5 | fairbanks
# Processing Record 44 of Set 5 | toliary
# City not found. Skipping...
# Processing Record 45 of Set 5 | mar del plata
# Processing Record 46 of Set 5 | bredasdorp
# Processing Record 47 of Set 5 | muli
# Processing Record 48 of Set 5 | methven
# Processing Record 49 of Set 5 | san jose
# Processing Record 50 of Set 5 | gelemso
# Processing Record 1 of Set 6 | tiksi
# Processing Record 2 of Set 6 | saint-augustin
# Processing Record 3 of Set 6 | cubara
# Processing Record 4 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 5 of Set 6 | sao joaquim da barra
# Processing Record 6 of Set 6 | haines junction
# Processing Record 7 of Set 6 | college
# Processing Record 8 of Set 6 | vila franca do campo
# Processing Record 9 of Set 6 | polunochnoye
# Processing Record 10 of Set 6 | westport
# Processing Record 11 of Set 6 | katakwi
# Processing Record 12 of Set 6 | salalah
# Processing Record 13 of Set 6 | cherskiy
# Processing Record 14 of Set 6 | lazaro cardenas
# Processing Record 15 of Set 6 | san policarpo
# Processing Record 16 of Set 6 | key west
# Processing Record 17 of Set 6 | bodden town
# Processing Record 18 of Set 6 | sharan
# Processing Record 19 of Set 6 | linhares
# Processing Record 20 of Set 6 | moerai
# Processing Record 21 of Set 6 | awjilah
# Processing Record 22 of Set 6 | provideniya
# Processing Record 23 of Set 6 | saint george
# Processing Record 24 of Set 6 | batalha
# Processing Record 25 of Set 6 | kavieng
# Processing Record 26 of Set 6 | lima
# Processing Record 27 of Set 6 | tarquinia
# Processing Record 28 of Set 6 | borinskoye
# Processing Record 29 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 30 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 31 of Set 6 | malkangiri
# Processing Record 32 of Set 6 | burnie
# Processing Record 33 of Set 6 | amapa
# Processing Record 34 of Set 6 | dali
# Processing Record 35 of Set 6 | rawson
# Processing Record 36 of Set 6 | novyy urengoy
# Processing Record 37 of Set 6 | samalaeulu
# City not found. Skipping...
# Processing Record 38 of Set 6 | luanda
# Processing Record 39 of Set 6 | sri aman
# Processing Record 40 of Set 6 | marsa matruh
# Processing Record 41 of Set 6 | port hardy
# Processing Record 42 of Set 6 | palmer
# Processing Record 43 of Set 6 | kuito
# Processing Record 44 of Set 6 | ojinaga
# Processing Record 45 of Set 6 | touros
# Processing Record 46 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 47 of Set 6 | broken hill
# Processing Record 48 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 49 of Set 6 | springbok
# Processing Record 50 of Set 6 | tuljapur
# Processing Record 1 of Set 7 | puerto quijarro
# Processing Record 2 of Set 7 | asau
# Processing Record 3 of Set 7 | nipawin
# Processing Record 4 of Set 7 | mao
# Processing Record 5 of Set 7 | ust-koksa
# Processing Record 6 of Set 7 | olhao
# Processing Record 7 of Set 7 | vardo
# Processing Record 8 of Set 7 | kushiro
# Processing Record 9 of Set 7 | sao francisco
# Processing Record 10 of Set 7 | yamada
# Processing Record 11 of Set 7 | muros
# Processing Record 12 of Set 7 | bafilo
# Processing Record 13 of Set 7 | hirara
# Processing Record 14 of Set 7 | samarai
# Processing Record 15 of Set 7 | dawei
# Processing Record 16 of Set 7 | znamenskoye
# Processing Record 17 of Set 7 | la rioja
# Processing Record 18 of Set 7 | riyadh
# Processing Record 19 of Set 7 | baie-comeau
# Processing Record 20 of Set 7 | dzhusaly
# City not found. Skipping...
# Processing Record 21 of Set 7 | fortuna
# Processing Record 22 of Set 7 | caravelas
# Processing Record 23 of Set 7 | lomovka
# Processing Record 24 of Set 7 | ancud
# Processing Record 25 of Set 7 | alofi
# Processing Record 26 of Set 7 | longyearbyen
# Processing Record 27 of Set 7 | marystown
# Processing Record 28 of Set 7 | bur gabo
# City not found. Skipping...
# Processing Record 29 of Set 7 | pangnirtung
# Processing Record 30 of Set 7 | medina
# Processing Record 31 of Set 7 | waw
# Processing Record 32 of Set 7 | simplicio mendes
# Processing Record 33 of Set 7 | mumford
# Processing Record 34 of Set 7 | baker city
# Processing Record 35 of Set 7 | wajima
# Processing Record 36 of Set 7 | san francisco del mar
# Processing Record 37 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 38 of Set 7 | peniche
# Processing Record 39 of Set 7 | brigantine
# Processing Record 40 of Set 7 | kuche
# City not found. Skipping...
# Processing Record 41 of Set 7 | gorgan
# Processing Record 42 of Set 7 | tete
# Processing Record 43 of Set 7 | chabahar
# Processing Record 44 of Set 7 | tuktoyaktuk
# Processing Record 45 of Set 7 | solon
# Processing Record 46 of Set 7 | carutapera
# Processing Record 47 of Set 7 | aden
# Processing Record 48 of Set 7 | port lincoln
# Processing Record 49 of Set 7 | namibe
# Processing Record 50 of Set 7 | ucluelet
# Processing Record 1 of Set 8 | kruisfontein
# Processing Record 2 of Set 8 | matamoros
# Processing Record 3 of Set 8 | ashland
# Processing Record 4 of Set 8 | kjollefjord
# Processing Record 5 of Set 8 | karakendzha
# City not found. Skipping...
# Processing Record 6 of Set 8 | gueret
# Processing Record 7 of Set 8 | beringovskiy
# Processing Record 8 of Set 8 | sawtell
# Processing Record 9 of Set 8 | lorengau
# Processing Record 10 of Set 8 | katha
# City not found. Skipping...
# Processing Record 11 of Set 8 | rome
# Processing Record 12 of Set 8 | pakwach
# City not found. Skipping...
# Processing Record 13 of Set 8 | ellisras
# Processing Record 14 of Set 8 | darhan
# Processing Record 15 of Set 8 | ciudad bolivar
# Processing Record 16 of Set 8 | lahat
# Processing Record 17 of Set 8 | airai
# Processing Record 18 of Set 8 | muborak
# Processing Record 19 of Set 8 | ituni
# City not found. Skipping...
# Processing Record 20 of Set 8 | dolbeau
# City not found. Skipping...
# Processing Record 21 of Set 8 | goundam
# Processing Record 22 of Set 8 | dongsheng
# Processing Record 23 of Set 8 | taksimo
# Processing Record 24 of Set 8 | pueblo
# Processing Record 25 of Set 8 | luderitz
# Processing Record 26 of Set 8 | brownsville
# Processing Record 27 of Set 8 | aklavik
# Processing Record 28 of Set 8 | ishigaki
# Processing Record 29 of Set 8 | norsup
# Processing Record 30 of Set 8 | pathein
# Processing Record 31 of Set 8 | taoudenni
# Processing Record 32 of Set 8 | marsh harbour
# Processing Record 33 of Set 8 | pindiga
# Processing Record 34 of Set 8 | mercedes
# Processing Record 35 of Set 8 | talnakh
# Processing Record 36 of Set 8 | khatanga
# Processing Record 37 of Set 8 | chicama
# Processing Record 38 of Set 8 | villarrica
# Processing Record 39 of Set 8 | fare
# Processing Record 40 of Set 8 | muzhi
# Processing Record 41 of Set 8 | bhainsa
# Processing Record 42 of Set 8 | ushtobe
# Processing Record 43 of Set 8 | chernyshevskiy
# Processing Record 44 of Set 8 | geraldton
# Processing Record 45 of Set 8 | manzhouli
# Processing Record 46 of Set 8 | los llanos de aridane
# Processing Record 47 of Set 8 | la ciotat
# Processing Record 48 of Set 8 | alindao
# Processing Record 49 of Set 8 | mitu
# Processing Record 50 of Set 8 | galle
# Processing Record 1 of Set 9 | shenavan
# Processing Record 2 of Set 9 | kenitra
# Processing Record 3 of Set 9 | henties bay
# Processing Record 4 of Set 9 | simbahan
# Processing Record 5 of Set 9 | juneau
# Processing Record 6 of Set 9 | pinheiro machado
# Processing Record 7 of Set 9 | tessalit
# Processing Record 8 of Set 9 | umba
# Processing Record 9 of Set 9 | poum
# Processing Record 10 of Set 9 | wulanhaote
# City not found. Skipping...
# Processing Record 11 of Set 9 | khuzhir
# Processing Record 12 of Set 9 | yairipok
# Processing Record 13 of Set 9 | zhigansk
# Processing Record 14 of Set 9 | hami
# Processing Record 15 of Set 9 | pahrump
# Processing Record 16 of Set 9 | batemans bay
# Processing Record 17 of Set 9 | grand baie
# Processing Record 18 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 19 of Set 9 | salamanca
# Processing Record 20 of Set 9 | vao
# Processing Record 21 of Set 9 | namatanai
# Processing Record 22 of Set 9 | temaraia
# City not found. Skipping...
# Processing Record 23 of Set 9 | castelo do piaui
# Processing Record 24 of Set 9 | vitre
# Processing Record 25 of Set 9 | russell
# Processing Record 26 of Set 9 | katherine
# Processing Record 27 of Set 9 | biltine
# Processing Record 28 of Set 9 | matara
# Processing Record 29 of Set 9 | egvekinot
# Processing Record 30 of Set 9 | pitmoaga
# Processing Record 31 of Set 9 | yar-sale
# Processing Record 32 of Set 9 | launceston
# Processing Record 33 of Set 9 | toamasina
# Processing Record 34 of Set 9 | sovetskiy
# Processing Record 35 of Set 9 | svetlogorsk
# Processing Record 36 of Set 9 | rio grande
# Processing Record 37 of Set 9 | marawi
# Processing Record 38 of Set 9 | cam ranh
# Processing Record 39 of Set 9 | ranau
# Processing Record 40 of Set 9 | saldanha
# Processing Record 41 of Set 9 | hai phong
# City not found. Skipping...
# Processing Record 42 of Set 9 | birnin kebbi
# Processing Record 43 of Set 9 | williams lake
# Processing Record 44 of Set 9 | sindand
# City not found. Skipping...
# Processing Record 45 of Set 9 | kodinsk
# Processing Record 46 of Set 9 | miranorte
# City not found. Skipping...
# Processing Record 47 of Set 9 | paradwip
# City not found. Skipping...
# Processing Record 48 of Set 9 | bethel
# Processing Record 49 of Set 9 | port-gentil
# Processing Record 50 of Set 9 | simao
# Processing Record 1 of Set 10 | yinchuan
# Processing Record 2 of Set 10 | byron bay
# Processing Record 3 of Set 10 | coahuayana
# Processing Record 4 of Set 10 | kaduy
# Processing Record 5 of Set 10 | nuuk
# Processing Record 6 of Set 10 | sussex
# Processing Record 7 of Set 10 | liberal
# Processing Record 8 of Set 10 | mount gambier
# Processing Record 9 of Set 10 | majholi
# Processing Record 10 of Set 10 | flinders
# Processing Record 11 of Set 10 | picota
# Processing Record 12 of Set 10 | kutum
# Processing Record 13 of Set 10 | iquique
# Processing Record 14 of Set 10 | filingue
# Processing Record 15 of Set 10 | the valley
# Processing Record 16 of Set 10 | poya
# Processing Record 17 of Set 10 | loandjili
# Processing Record 18 of Set 10 | presidencia roque saenz pena
# Processing Record 19 of Set 10 | riberalta
# Processing Record 20 of Set 10 | tuxpan
# Processing Record 21 of Set 10 | lishan
# Processing Record 22 of Set 10 | serebryansk
# Processing Record 23 of Set 10 | kulunda
# Processing Record 24 of Set 10 | tabarqah
# City not found. Skipping...
# Processing Record 25 of Set 10 | surt
# Processing Record 26 of Set 10 | shagonar
# Processing Record 27 of Set 10 | iquitos
# Processing Record 28 of Set 10 | sataua
# City not found. Skipping...
# Processing Record 29 of Set 10 | itarema
# Processing Record 30 of Set 10 | rawannawi
# City not found. Skipping...
# Processing Record 31 of Set 10 | botshabelo
# Processing Record 32 of Set 10 | gunjur
# Processing Record 33 of Set 10 | karamay
# City not found. Skipping...
# Processing Record 34 of Set 10 | mehamn
# Processing Record 35 of Set 10 | saint-georges
# Processing Record 36 of Set 10 | baculin
# Processing Record 37 of Set 10 | dukat
# Processing Record 38 of Set 10 | quatre cocos
# Processing Record 39 of Set 10 | ostersund
# Processing Record 40 of Set 10 | atar
# Processing Record 41 of Set 10 | kieta
# Processing Record 42 of Set 10 | elban
# Processing Record 43 of Set 10 | siilinjarvi
# Processing Record 44 of Set 10 | neftcala
# Processing Record 45 of Set 10 | leningradskiy
# Processing Record 46 of Set 10 | susner
# Processing Record 47 of Set 10 | kiunga
# Processing Record 48 of Set 10 | calama
# Processing Record 49 of Set 10 | husavik
# Processing Record 50 of Set 10 | okhotsk
# Processing Record 1 of Set 11 | garhi khairo
# Processing Record 2 of Set 11 | fenyi
# Processing Record 3 of Set 11 | iqaluit
# Processing Record 4 of Set 11 | ponta do sol
# Processing Record 5 of Set 11 | avera
# Processing Record 6 of Set 11 | haibowan
# City not found. Skipping...
# Processing Record 7 of Set 11 | alta floresta
# Processing Record 8 of Set 11 | rio gallegos
# Processing Record 9 of Set 11 | zabid
# Processing Record 10 of Set 11 | arlit
# Processing Record 11 of Set 11 | morondava
# Processing Record 12 of Set 11 | mwinilunga
# Processing Record 13 of Set 11 | asosa
# Processing Record 14 of Set 11 | seydi
# Processing Record 15 of Set 11 | dakar
# Processing Record 16 of Set 11 | yumen
# Processing Record 17 of Set 11 | batticaloa
# Processing Record 18 of Set 11 | tongchuan
# Processing Record 19 of Set 11 | lagoa
# Processing Record 20 of Set 11 | kashin
# Processing Record 21 of Set 11 | labuhan
# Processing Record 22 of Set 11 | nemuro
# Processing Record 23 of Set 11 | yulara
# Processing Record 24 of Set 11 | ust-nera
# Processing Record 25 of Set 11 | barra do garcas
# Processing Record 26 of Set 11 | biak
# Processing Record 27 of Set 11 | lujan
# Processing Record 28 of Set 11 | nago
# Processing Record 29 of Set 11 | lodi
# Processing Record 30 of Set 11 | paamiut
# Processing Record 31 of Set 11 | hohhot
# Processing Record 32 of Set 11 | deputatskiy
# Processing Record 33 of Set 11 | semnan
# Processing Record 34 of Set 11 | warri
# Processing Record 35 of Set 11 | lusambo
# Processing Record 36 of Set 11 | ylojarvi
# Processing Record 37 of Set 11 | taburi
# City not found. Skipping...
# Processing Record 38 of Set 11 | sedelnikovo
# City not found. Skipping...
# Processing Record 39 of Set 11 | hoquiam
# Processing Record 40 of Set 11 | surman
# Processing Record 41 of Set 11 | sitka
# Processing Record 42 of Set 11 | acajutla
# Processing Record 43 of Set 11 | tocopilla
# Processing Record 44 of Set 11 | hendek
# Processing Record 45 of Set 11 | camacha
# Processing Record 46 of Set 11 | churapcha
# Processing Record 47 of Set 11 | shimoda
# Processing Record 48 of Set 11 | beira
# Processing Record 49 of Set 11 | coquimbo
# Processing Record 50 of Set 11 | sarangani
# Processing Record 1 of Set 12 | port blair
# Processing Record 2 of Set 12 | xintai
# Processing Record 3 of Set 12 | sept-iles
# Processing Record 4 of Set 12 | isangel
# Processing Record 5 of Set 12 | olinda
# Processing Record 6 of Set 12 | nisia floresta
# Processing Record 7 of Set 12 | tunduru
# City not found. Skipping...
# Processing Record 8 of Set 12 | jesus carranza
# Processing Record 9 of Set 12 | aswan
# Processing Record 10 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 11 of Set 12 | kendari
# Processing Record 12 of Set 12 | zlatoustovsk
# City not found. Skipping...
# Processing Record 13 of Set 12 | grindavik
# Processing Record 14 of Set 12 | porbandar
# Processing Record 15 of Set 12 | ballinasloe
# Processing Record 16 of Set 12 | ormara
# Processing Record 17 of Set 12 | diamantino
# Processing Record 18 of Set 12 | salisbury
# Processing Record 19 of Set 12 | raozan
# City not found. Skipping...
# Processing Record 20 of Set 12 | monrovia
# Processing Record 21 of Set 12 | gazli
# Processing Record 22 of Set 12 | sargatskoye
# Processing Record 23 of Set 12 | yeniseysk
# Processing Record 24 of Set 12 | hailar
# Processing Record 25 of Set 12 | asayita
# City not found. Skipping...
# Processing Record 26 of Set 12 | panguipulli
# Processing Record 27 of Set 12 | hue
# Processing Record 28 of Set 12 | constitucion
# Processing Record 29 of Set 12 | damara
# Processing Record 30 of Set 12 | mandalgovi
# Processing Record 31 of Set 12 | nawalgarh
# Processing Record 32 of Set 12 | vila
# Processing Record 33 of Set 12 | conceicao do araguaia
# Processing Record 34 of Set 12 | bereda
# Processing Record 35 of Set 12 | fasa
# Processing Record 36 of Set 12 | dwarka
# Processing Record 37 of Set 12 | dondo
# Processing Record 38 of Set 12 | zadonsk
# Processing Record 39 of Set 12 | jhang
# Processing Record 40 of Set 12 | camp verde
# Processing Record 41 of Set 12 | bundaberg
# Processing Record 42 of Set 12 | coihaique
# Processing Record 43 of Set 12 | tagusao
# Processing Record 44 of Set 12 | aksu
# Processing Record 45 of Set 12 | karaul
# City not found. Skipping...
# Processing Record 46 of Set 12 | itatiaia
# Processing Record 47 of Set 12 | erzin
# Processing Record 48 of Set 12 | morag
# Processing Record 49 of Set 12 | muroto
# Processing Record 50 of Set 12 | cururupu
# Processing Record 1 of Set 13 | saint-francois
# Processing Record 2 of Set 13 | marondera
# Processing Record 3 of Set 13 | mnogovershinnyy
# Processing Record 4 of Set 13 | buin
# Processing Record 5 of Set 13 | yerbogachen
# Processing Record 6 of Set 13 | puerto madero
# Processing Record 7 of Set 13 | ylivieska
# Processing Record 8 of Set 13 | louisbourg
# City not found. Skipping...
# Processing Record 9 of Set 13 | crema
# Processing Record 10 of Set 13 | santa cruz de la palma
# Processing Record 11 of Set 13 | praxedis guerrero
# Processing Record 12 of Set 13 | cap malheureux
# Processing Record 13 of Set 13 | ustka
# Processing Record 14 of Set 13 | srandakan
# Processing Record 15 of Set 13 | chachapoyas
# Processing Record 16 of Set 13 | yara
# Processing Record 17 of Set 13 | chanute
# Processing Record 18 of Set 13 | ambilobe
# Processing Record 19 of Set 13 | juifang
# City not found. Skipping...
# Processing Record 20 of Set 13 | warqla
# City not found. Skipping...
# Processing Record 21 of Set 13 | vestmannaeyjar
# Processing Record 22 of Set 13 | umm kaddadah
# Processing Record 23 of Set 13 | wad madani
# Processing Record 24 of Set 13 | sibu
# Processing Record 25 of Set 13 | imbituva
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
3city_data_df
# Out:
#                City Country      Lat       Lng  Max Temp  Humidity  \
# 0             Kapaa      US  22.0752 -159.3190     71.92        84
# 1        Lavrentiya      RU  65.5833 -171.0000    -25.35        91
# 2        Georgetown      MY   5.4112  100.3354     80.89        93
# 3           Rikitea      PF -23.1203 -134.9692     78.75        67
# 4              Tual      ID  -5.6667  132.7500     82.47        79
# ..              ...     ...      ...       ...       ...       ...
# 564  Vestmannaeyjar      IS  63.4427  -20.2734     32.99        64
# 565    Umm Kaddadah      SD  13.6017   26.6876     70.84        12
# 566      Wad Madani      SD  14.4012   33.5199     82.13        23
# 567            Sibu      MY   2.3000  111.8167     77.31       100
# 568        Imbituva      BR -25.2300  -50.6044     79.32        46
#
#      Cloudiness  Wind Speed Current Description
# 0            20        9.22          light rain
# 1            57        7.14       broken clouds
# 2            20        0.00          few clouds
# 3             3       16.31           clear sky
# 4            94       14.58     overcast clouds
# ..          ...         ...                 ...
# 564           0        8.05           clear sky
# 565          32       13.02    scattered clouds
# 566          54        8.86       broken clouds
# 567          40        2.30       moderate rain
# 568          67        4.09       broken clouds
#
# [569 rows x 9 columns]

# %%
# Confirm count
city_data_df.count()
# Out:
# City                   569
# Country                569
# Lat                    569
# Lng                    569
# Max Temp               569
# Humidity               569
# Cloudiness             569
# Wind Speed             569
# Current Description    569
# dtype: int64

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
